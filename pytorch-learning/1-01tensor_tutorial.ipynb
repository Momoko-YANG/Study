# %%
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 get_ipython().run_line_magic('matplotlib', 'inline')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\interactiveshell.py:2504, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2502     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2503 with self.builtin_trap:
# -> 2504     result = fn(*args, **kwargs)
#    2506 # The code below prevents the output from being displayed
#    2507 # when using magics with decorator @output_can_be_silenced
#    2508 # when the last Python token in the expression is a ';'.
#    2509 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\magics\pylab.py:103, in PylabMagics.matplotlib(self, line)
#      98     print(
#      99         "Available matplotlib backends: %s"
#     100         % _list_matplotlib_backends_and_gui_loops()
#     101     )
#     102 else:
# --> 103     gui, backend = self.shell.enable_matplotlib(args.gui)
#     104     self._show_matplotlib_backend(args.gui, backend)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\interactiveshell.py:3787, in InteractiveShell.enable_matplotlib(self, gui)
#    3784     import matplotlib_inline.backend_inline
#    3786 from IPython.core import pylabtools as pt
# -> 3787 gui, backend = pt.find_gui_and_backend(gui, self.pylab_gui_select)
#    3789 if gui != None:
#    3790     # If we have our first gui selection, store it
#    3791     if self.pylab_gui_select is None:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\pylabtools.py:338, in find_gui_and_backend(gui, gui_select)
#     321 def find_gui_and_backend(gui=None, gui_select=None):
#     322     """Given a gui string return the gui and mpl backend.
#     323
#     324     Parameters
#    (...)    335     'WXAgg','Qt4Agg','module://matplotlib_inline.backend_inline','agg').
#     336     """
# --> 338     import matplotlib
#     340     if _matplotlib_manages_backends():
#     341         backend_registry = matplotlib.backends.registry.backend_registry
#
# ModuleNotFoundError: No module named 'matplotlib'

# %% [markdown]
# #### Pytorch是什么？
# 基于Python的科学计算包，服务于以下两种场景：
# - 作为NumPy的替代品，可以使用GPU的强大计算能力
# - 提供最大的灵活性和高速的深度学习研究平台

# %% [markdown]
# #### Tensor
# 在Pytorch中Tensors可以使用GPU进行计算

# %%
from __future__ import print_function
import torch

x = troch.empty(5, 3) # 创建一个未初始化的5x3矩阵
print(x)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 from __future__ import print_function
# ----> 2 import torch
#       4 x = troch.empty(5, 3) # 创建一个未初始化的5x3矩阵
#       5 print(x)
#
# ModuleNotFoundError: No module named 'torch'

# %%
x = troch.rand(5,3) # 创建一个随机初始化的5x3矩阵
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 x = troch.rand(5,3) # 创建一个随机初始化的5x3矩阵
#       2 print(x)
#
# NameError: name 'troch' is not defined

# %%
x = torch.zeros(5, 3, dtype=torch.long) # 创建一个5x3的零矩阵，数据类型为long
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 x = torch.zeros(5, 3, dtype=torch.long) # 创建一个5x3的零矩阵，数据类型为long
#       2 print(x)
#
# NameError: name 'torch' is not defined

# %%
x = torch.tensor([5.5, 3]) # 直接从数据创建张量
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 x = torch.tensor([5.5, 3]) # 直接从数据创建张量
#       2 print(x)
#
# NameError: name 'torch' is not defined

# %%
x = x.new_ones(5,3,dtype=torch.double) # new_* 方法根据现有张量的属性创建新张量
print(x)

x = troch.randn_like(x, dtype=torch.float) # 重写数据类型
print(x) # 输出结果与上面相同尺寸，但数据类型不同

# %% [markdown]
# 使用size方法于NumPy的shape属性返回的相同，张量也支持shape属性

# %%
print(x.size())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(x.size())
#
# NameError: name 'x' is not defined

# %% [markdown]
# "torch.size"返回值是tuple类型，支持tuple类型的所有操作。

# %% [markdown]
# #### 加法运算

# %%
y = torch.rand(5,3)
print(x+y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 y = torch.rand(5,3)
#       2 print(x+y)
#
# NameError: name 'torch' is not defined

# %%
print(torch.add(x,y))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(torch.add(x,y))
#
# NameError: name 'torch' is not defined

# %%
result = troch.empty(5,3) # 可以通过out参数指定输出张量
torch.add(x,y,out = result)
print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 result = troch.empty(5,3)
#       2 torch.add(x,y,out = result)
#
# NameError: name 'troch' is not defined

# %%
y.add_(x) # 这个语句会改变y
print(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 y.add_(x) # 这个语句会改变y
#       2 print(y)
#
# NameError: name 'y' is not defined

# %% [markdown]
# 任何以`_`结尾的操作都会用结果替换原变量。例如：`x.copy_(y)`,`x.t_()`都会改变x

# %%
print(x[:,1]) # 取第二列所有元素
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 print(x[:,1]) # 取第二列所有元素
#
# NameError: name 'x' is not defined

# %% [markdown]
# `torch.view`可以改变张量的维度和大小

# %%
x = troch.randn(4,4) 
y = x.view(16) # 改变维度为1x16
z = x.view(-1,8) # -1表示自适应计算该维度大小，这里变为2x8
print(x.size(),y.size(),z.size())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 x = troch.randn(4,4)
#       2 y = x.view(16) # 改变维度为1x16
#       3 z = x.view(-1,8) # -1表示自适应计算该维度大小，这里变为2x8
#
# NameError: name 'troch' is not defined

# %%
x = torch.randn(1)  # 创建一个标量张量
print(x)
print(x.item())  # 使用item()获取张量的值

# %% [markdown]
# #### NumPy转换
# Torch Tensor与NumPy数组共享底层内存地址，修改一个会导致另一个的变化。
# 将一个Torch Tensor转换为NumPy数组

# %%
a = torch.ones(5) # 创建一个长度为5的全1张量
print(a)

# %%
b = a.numpy() # 将Torch张量转换为NumPy数组
print(b)

# %%
a.add(1)    
print(a)
print(b)

# %%
import numpy as np
a = np.ones(5)  # 创建一个长度为5的NumPy数组
b = torch.from_numpy(a)  # 将NumPy数组转换为Torch张量
np.add(a,1,out=a)  # NumPy数组加1
print(a)
print(b)  # Torch张量也会改变

# %% [markdown]
# 所有的Tensor类型默认都是基于CPU，CharTensor类型不支持到NumPy的转换。

# %% [markdown]
# CUDA张量使用`.to`方法可以将Tensor移动到任何设备中

# %%
# is_available()函数可以检查CUDA是否可用
#`torch.device`对象表示我们想要将张量存储在哪个设备上

if troch.cuda.is_available():
    device = torch.decvice("cuda")         # 一个CUDA设备对象
    y = torch.ones_like(x, device= device)   # 直接创建一个CUDA张量
    x = x.to(device)                          # 或者使用`.to`方法将张量移动到CUDA设备上
    z = x + y
    print(z)
    print(z.to("cpu", torch.double))         # 使用`.to`方法将张量移动到CPU并更改数据类型
